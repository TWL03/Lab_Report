# %%
import matplotlib.pyplot as plt

# Data from the image
v = [780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220]
rate = [0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
        37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444]
# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(v, rate, marker='o', linestyle='-', color='b')
plt.title('Count Rate vs Applied Voltage')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create spline
spline = make_interp_spline(v, rate)

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)
rate_smooth = spline(v_smooth)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(v_smooth, rate_smooth, color='b', label='Smoothed Curve')
plt.scatter(v, rate, color='r', marker='x', label='Data Points')
plt.title('Count Rate vs Applied Voltage')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import BSpline, splrep, splev

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Generate a B-spline representation
spl = splrep(v, rate)
v_smooth = np.linspace(v.min(), v.max(), 500)
rate_smooth = splev(v_smooth, spl)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(v_smooth, rate_smooth, color='b', label='B-Spline Smoothed Curve')
plt.scatter(v, rate, color='r', marker='x', label='Data Points')
plt.title('Count Rate vs Applied Voltage')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import CubicSpline

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create cubic spline interpolation
cs = CubicSpline(v, rate)

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)
rate_smooth = cs(v_smooth)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(v_smooth, rate_smooth, color='b', label='Cubic Spline Smoothed Curve')
plt.scatter(v, rate, color='r', marker='o', label='Data Points')
plt.title('Count Rate vs Applied Voltage')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create quadratic interpolation
quadratic_interp = interp1d(v, rate, kind='quadratic')

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)
rate_smooth = quadratic_interp(v_smooth)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(v_smooth, rate_smooth, color='b', label='Quadratic Interpolation Smoothed Curve')
plt.scatter(v, rate, color='r', marker='o', label='Data Points')
plt.title('Count Rate vs Applied Voltage')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create a polynomial fit
degree = 5  # You can change the degree of the polynomial for a different fit
polynomial_coefficients = np.polyfit(v, rate, degree)
polynomial_fit = np.polyval(polynomial_coefficients, v)

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)
rate_smooth = np.polyval(polynomial_coefficients, v_smooth)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(v_smooth, rate_smooth, color='b', label=f'Polynomial Fit (Degree {degree})')
plt.scatter(v, rate, color='r', marker='o', label='Data Points')
plt.title('Count Rate vs Applied Voltage')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import Akima1DInterpolator

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create Akima interpolator
akima_interp = Akima1DInterpolator(v, rate)

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)
rate_smooth = akima_interp(v_smooth)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(v_smooth, rate_smooth, color='b', label='Akima Interpolation')
plt.scatter(v, rate, color='r', marker='o', label='Data Points')
plt.title('Count Rate vs Applied Voltage')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import PchipInterpolator

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create PCHIP interpolator
pchip_interp = PchipInterpolator(v, rate)

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)
rate_smooth = pchip_interp(v_smooth)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(v_smooth, rate_smooth, color='b', label='PCHIP Interpolation')
plt.scatter(v, rate, color='r', marker='o', label='Data Points')
plt.title('Count Rate vs Applied Voltage')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create nearest-neighbor interpolator
nearest_interp = interp1d(v, rate, kind='nearest')

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)
rate_smooth = nearest_interp(v_smooth)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(v_smooth, rate_smooth, color='b', label='Nearest-Neighbor Interpolation')
plt.scatter(v, rate, color='r', marker='o', label='Data Points')
plt.title('Count Rate vs Applied Voltage')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create zero-order hold interpolator
step_interp = interp1d(v, rate, kind='previous')

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)
rate_smooth = step_interp(v_smooth)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(v_smooth, rate_smooth, color='b', label='Zero-Order Hold (Step Function)')
plt.scatter(v, rate, color='r', marker='o', label='Data Points')
plt.title('Count Rate vs Applied Voltage')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create linear interpolator
linear_interp = interp1d(v, rate)

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)
rate_smooth = linear_interp(v_smooth)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(v_smooth, rate_smooth, color='b', label='Linear Interpolation')
plt.scatter(v, rate, color='r', marker='o', label='Data Points')
plt.title('Count Rate vs Applied Voltage')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import Rbf

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create RBF interpolator
rbf_interp = Rbf(v, rate, function='multiquadric')

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)
rate_smooth = rbf_interp(v_smooth)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(v_smooth, rate_smooth, color='b', label='RBF Interpolation')
plt.scatter(v, rate, color='r', marker='o', label='Data Points')
plt.title('Count Rate vs Applied Voltage')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import UnivariateSpline

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create univariate spline interpolator
uni_spline = UnivariateSpline(v, rate, s=0)

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)
rate_smooth = uni_spline(v_smooth)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(v_smooth, rate_smooth, color='b', label='Univariate Spline Interpolation')
plt.scatter(v, rate, color='r', marker='o', label='Data Points')
plt.title('Count Rate vs Applied Voltage')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.neighbors import KernelDensity

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create kernel density estimator
kde = KernelDensity(kernel='gaussian', bandwidth=20).fit(v[:, None])

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)
rate_smooth = np.exp(kde.score_samples(v_smooth[:, None]))

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(v_smooth, rate_smooth, color='b', label='Kernel Regression (Nadaraya-Watson)')
plt.scatter(v, rate, color='r', marker='o', label='Data Points')
plt.title('Count Rate vs Applied Voltage')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import Rbf

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create RBF interpolator
rbf_interp = Rbf(v, rate, function='multiquadric')

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)
rate_smooth = rbf_interp(v_smooth)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(v_smooth, rate_smooth, color='b', label='Multiquadric RBF Interpolation')
plt.scatter(v, rate, color='r', marker='o', label='Data Points')
plt.title('Count Rate vs Applied Voltage')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import Rbf

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create thin plate spline RBF interpolator
tps_interp = Rbf(v, rate, function='thin_plate')

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)
rate_smooth = tps_interp(v_smooth)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(v_smooth, rate_smooth, color='b', label='Thin Plate Spline Interpolation')
plt.scatter(v, rate, color='r', marker='o', label='Data Points')
plt.title('Count Rate vs Applied Voltage')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d, BSpline, splrep, splev, Akima1DInterpolator, PchipInterpolator

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)

# Linear Interpolation
linear_interp = interp1d(v, rate)
rate_smooth_linear = linear_interp(v_smooth)

# B-Spline Interpolation
spl = splrep(v, rate)
rate_smooth_bspline = splev(v_smooth, spl)

# Akima Interpolation
akima_interp = Akima1DInterpolator(v, rate)
rate_smooth_akima = akima_interp(v_smooth)

# PCHIP Interpolation
pchip_interp = PchipInterpolator(v, rate)
rate_smooth_pchip = pchip_interp(v_smooth)

# Plotting the data
plt.figure(figsize=(12, 8))

# Linear Interpolation
plt.subplot(2, 2, 1)
plt.plot(v_smooth, rate_smooth_linear, color='b', label='Linear Interpolation')
plt.scatter(v, rate, color='r', marker='x', label='Data Points')
plt.title('Linear Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# B-Spline Interpolation
plt.subplot(2, 2, 2)
plt.plot(v_smooth, rate_smooth_bspline, color='b', label='B-Spline Smoothed Curve')
plt.scatter(v, rate, color='r', marker='x', label='Data Points')
plt.title('B-Spline Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# Akima Interpolation
plt.subplot(2, 2, 3)
plt.plot(v_smooth, rate_smooth_akima, color='b', label='Akima Interpolation')
plt.scatter(v, rate, color='r', marker='x', label='Data Points')
plt.title('Akima Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# PCHIP Interpolation
plt.subplot(2, 2, 4)
plt.plot(v_smooth, rate_smooth_pchip, color='b', label='PCHIP Interpolation')
plt.scatter(v, rate, color='r', marker='x', label='Data Points')
plt.title('PCHIP Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d, splrep, splev, Akima1DInterpolator, PchipInterpolator

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Assuming arbitrary errors for demonstration
v_error = np.full_like(v, 20)  # Error in voltage
rate_error = np.full_like(rate, 2)  # Error in count rate

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)

# Linear Interpolation
linear_interp = interp1d(v, rate)
rate_smooth_linear = linear_interp(v_smooth)

# B-Spline Interpolation
spl = splrep(v, rate)
rate_smooth_bspline = splev(v_smooth, spl)

# Akima Interpolation
akima_interp = Akima1DInterpolator(v, rate)
rate_smooth_akima = akima_interp(v_smooth)

# PCHIP Interpolation
pchip_interp = PchipInterpolator(v, rate)
rate_smooth_pchip = pchip_interp(v_smooth)

# Plotting the data
plt.figure(figsize=(12, 8))

# Linear Interpolation
plt.subplot(2, 2, 1)
plt.plot(v_smooth, rate_smooth_linear, color='b', label='Linear Interpolation')
plt.errorbar(v, rate, xerr=v_error, yerr=rate_error, fmt='r.', label='Data Points with Error',elinewidth=2, capsize=4)
plt.title('Linear Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# B-Spline Interpolation
plt.subplot(2, 2, 2)
plt.plot(v_smooth, rate_smooth_bspline, color='b', label='B-Spline Smoothed Curve')
plt.errorbar(v, rate, xerr=v_error, yerr=rate_error, fmt='r.', label='Data Points with Error',elinewidth=2, capsize=4)
plt.title('B-Spline Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# Akima Interpolation
plt.subplot(2, 2, 3)
plt.plot(v_smooth, rate_smooth_akima, color='b', label='Akima Interpolation')
plt.errorbar(v, rate, xerr=v_error, yerr=rate_error, fmt='r.', label='Data Points with Error',elinewidth=2, capsize=4)
plt.title('Akima Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# PCHIP Interpolation
plt.subplot(2, 2, 4)
plt.plot(v_smooth, rate_smooth_pchip, color='b', label='PCHIP Interpolation')
plt.errorbar(v, rate, xerr=v_error, yerr=rate_error, fmt='r.', label='Data Points with Error',elinewidth=2, capsize=4)
plt.title('PCHIP Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d, splrep, splev, Akima1DInterpolator, PchipInterpolator

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)

# Linear Interpolation
linear_interp = interp1d(v, rate)
rate_smooth_linear = linear_interp(v_smooth)

# B-Spline Interpolation
spl = splrep(v, rate)
rate_smooth_bspline = splev(v_smooth, spl)

# Akima Interpolation
akima_interp = Akima1DInterpolator(v, rate)
rate_smooth_akima = akima_interp(v_smooth)

# PCHIP Interpolation
pchip_interp = PchipInterpolator(v, rate)
rate_smooth_pchip = pchip_interp(v_smooth)

def compute_geiger_plateau_slope(v, rate):
    # Identify the threshold voltage (V_t) and breakdown voltage (V_a)
    # Assuming V_t is where count rate starts to plateau and V_a is where rapid increase is observed
    # For this implementation, we will select the points manually or you can automate it based on your criteria
    V_t_index = np.argmax(rate > 90)  # Example criterion for threshold voltage
    V_a_index = np.argmax(rate > 130)  # Example criterion for breakdown voltage

    V_t = v[V_t_index]
    V_a = v[V_a_index]
    R_t = rate[V_t_index]
    R_a = rate[V_a_index]

    # Compute the slope using the given formula
    slope = ((R_a - R_t) / (0.5 * (R_a + R_t) * (V_a - V_t))) * 100

    return slope, V_t, V_a, R_t, R_a

# Compute the slope of the Geiger plateau
slope, V_t, V_a, R_t, R_a = compute_geiger_plateau_slope(v, rate)

# Plotting the data
plt.figure(figsize=(12, 8))

# Linear Interpolation
plt.subplot(2, 2, 1)
plt.plot(v_smooth, rate_smooth_linear, color='b', label='Linear Interpolation')
plt.errorbar(v, rate, xerr=np.full_like(v, 5), yerr=np.full_like(rate, 2), fmt='r.', label='Data Points with Error')
plt.axvline(V_t, color='g', linestyle='--', label=f'Vt = {V_t} V')
plt.axvline(V_a, color='m', linestyle='--', label=f'Va = {V_a} V')
plt.title('Linear Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# B-Spline Interpolation
plt.subplot(2, 2, 2)
plt.plot(v_smooth, rate_smooth_bspline, color='b', label='B-Spline Smoothed Curve')
plt.errorbar(v, rate, xerr=np.full_like(v, 5), yerr=np.full_like(rate, 2), fmt='r.', label='Data Points with Error')
plt.axvline(V_t, color='g', linestyle='--', label=f'Vt = {V_t} V')
plt.axvline(V_a, color='m', linestyle='--', label=f'Va = {V_a} V')
plt.title('B-Spline Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# Akima Interpolation
plt.subplot(2, 2, 3)
plt.plot(v_smooth, rate_smooth_akima, color='b', label='Akima Interpolation')
plt.errorbar(v, rate, xerr=np.full_like(v, 5), yerr=np.full_like(rate, 2), fmt='r.', label='Data Points with Error')
plt.axvline(V_t, color='g', linestyle='--', label=f'Vt = {V_t} V')
plt.axvline(V_a, color='m', linestyle='--', label=f'Va = {V_a} V')
plt.title('Akima Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# PCHIP Interpolation
plt.subplot(2, 2, 4)
plt.plot(v_smooth, rate_smooth_pchip, color='b', label='PCHIP Interpolation')
plt.errorbar(v, rate, xerr=np.full_like(v, 5), yerr=np.full_like(rate, 2), fmt='r.', label='Data Points with Error')
plt.axvline(V_t, color='g', linestyle='--', label=f'Vt = {V_t} V')
plt.axvline(V_a, color='m', linestyle='--', label=f'Va = {V_a} V')
plt.title('PCHIP Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

print(f"Slope of the Geiger plateau: {slope:.2f}%")
print(f"Threshold Voltage (V_t): {V_t} V, Count Rate (R_t): {R_t}")
print(f"Breakdown Voltage (V_a): {V_a} V, Count Rate (R_a): {R_a}")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_25088\184342305.py:42: RuntimeWarning: invalid value encountered in scalar divide
#   slope = ((R_a - R_t) / (0.5 * (R_a + R_t) * (V_a - V_t))) * 100
# Slope of the Geiger plateau: nan%
# Threshold Voltage (V_t): 780 V, Count Rate (R_t): 0.0
# Breakdown Voltage (V_a): 780 V, Count Rate (R_a): 0.0

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d, splrep, splev, Akima1DInterpolator, PchipInterpolator

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)

# Linear Interpolation
linear_interp = interp1d(v, rate)
rate_smooth_linear = linear_interp(v_smooth)

# B-Spline Interpolation
spl = splrep(v, rate)
rate_smooth_bspline = splev(v_smooth, spl)

# Akima Interpolation
akima_interp = Akima1DInterpolator(v, rate)
rate_smooth_akima = akima_interp(v_smooth)

# PCHIP Interpolation
pchip_interp = PchipInterpolator(v, rate)
rate_smooth_pchip = pchip_interp(v_smooth)

def compute_geiger_plateau_slope(v, rate):
    # Calculate gradient
    gradients = np.gradient(rate, v)
    
    # Identify threshold voltage (V_t) where gradient first increases significantly
    threshold_indices = np.where(gradients > np.percentile(gradients, 95))[0]
    V_t_index = threshold_indices[0] if threshold_indices.size > 0 else 0

    # Identify breakdown voltage (V_a) where gradient increases significantly again
    breakdown_indices = np.where(gradients > np.percentile(gradients, 95))[0]
    V_a_index = breakdown_indices[-1] if breakdown_indices.size > 0 else len(v) - 1

    V_t = v[V_t_index]
    V_a = v[V_a_index]
    R_t = rate[V_t_index]
    R_a = rate[V_a_index]

    # Compute the slope using the given formula
    slope = ((R_a - R_t) / (0.5 * (R_a + R_t) * (V_a - V_t))) * 100

    return slope, V_t, V_a, R_t, R_a

# Compute the slope of the Geiger plateau
slope, V_t, V_a, R_t, R_a = compute_geiger_plateau_slope(v, rate)

# Plotting the data
plt.figure(figsize=(12, 8))

# Linear Interpolation
plt.subplot(2, 2, 1)
plt.plot(v_smooth, rate_smooth_linear, color='b', label='Linear Interpolation')
plt.errorbar(v, rate, xerr=np.full_like(v, 5), yerr=np.full_like(rate, 2), fmt='r.', label='Data Points with Error')
plt.axvline(V_t, color='g', linestyle='--', label=f'Vt = {V_t} V')
plt.axvline(V_a, color='m', linestyle='--', label=f'Va = {V_a} V')
plt.title('Linear Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# B-Spline Interpolation
plt.subplot(2, 2, 2)
plt.plot(v_smooth, rate_smooth_bspline, color='b', label='B-Spline Smoothed Curve')
plt.errorbar(v, rate, xerr=np.full_like(v, 5), yerr=np.full_like(rate, 2), fmt='r.', label='Data Points with Error')
plt.axvline(V_t, color='g', linestyle='--', label=f'Vt = {V_t} V')
plt.axvline(V_a, color='m', linestyle='--', label=f'Va = {V_a} V')
plt.title('B-Spline Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# Akima Interpolation
plt.subplot(2, 2, 3)
plt.plot(v_smooth, rate_smooth_akima, color='b', label='Akima Interpolation')
plt.errorbar(v, rate, xerr=np.full_like(v, 5), yerr=np.full_like(rate, 2), fmt='r.', label='Data Points with Error')
plt.axvline(V_t, color='g', linestyle='--', label=f'Vt = {V_t} V')
plt.axvline(V_a, color='m', linestyle='--', label=f'Va = {V_a} V')
plt.title('Akima Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# PCHIP Interpolation
plt.subplot(2, 2, 4)
plt.plot(v_smooth, rate_smooth_pchip, color='b', label='PCHIP Interpolation')
plt.errorbar(v, rate, xerr=np.full_like(v, 5), yerr=np.full_like(rate, 2), fmt='r.', label='Data Points with Error')
plt.axvline(V_t, color='g', linestyle='--', label=f'Vt = {V_t} V')
plt.axvline(V_a, color='m', linestyle='--', label=f'Va = {V_a} V')
plt.title('PCHIP Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

print(f"Slope of the Geiger plateau: {slope:.2f}%")
print(f"Threshold Voltage (V_t): {V_t} V, Count Rate (R_t): {R_t}")
print(f"Breakdown Voltage (V_a): {V_a} V, Count Rate (R_a): {R_a}")
# Out:
# Slope of the Geiger plateau: 0.39%
# Threshold Voltage (V_t): 800 V, Count Rate (R_t): 6.61111111
# Breakdown Voltage (V_a): 1220 V, Count Rate (R_a): 67.7444444

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d, splrep, splev, Akima1DInterpolator, PchipInterpolator

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)

# Linear Interpolation
linear_interp = interp1d(v, rate)
rate_smooth_linear = linear_interp(v_smooth)

# B-Spline Interpolation
spl = splrep(v, rate)
rate_smooth_bspline = splev(v_smooth, spl)

# Akima Interpolation
akima_interp = Akima1DInterpolator(v, rate)
rate_smooth_akima = akima_interp(v_smooth)

# PCHIP Interpolation
pchip_interp = PchipInterpolator(v, rate)
rate_smooth_pchip = pchip_interp(v_smooth)

def compute_geiger_plateau_slope(v, rate):
    # Calculate gradient
    gradients = np.gradient(rate, v)
    
    # Calculate the second gradient (change of gradients)
    second_gradients = np.gradient(gradients, v)

    # Identify threshold voltage (V_t) where gradient suddenly decreases significantly
    V_t_index = np.argmin(second_gradients)
    # Identify breakdown voltage (V_a) where gradient suddenly increases significantly
    V_a_index = np.argmax(second_gradients)

    V_t = v[V_t_index]
    V_a = v[V_a_index]
    R_t = rate[V_t_index]
    R_a = rate[V_a_index]

    # Compute the slope using the given formula
    slope = ((R_a - R_t) / (0.5 * (R_a + R_t) * (V_a - V_t))) * 100

    return slope, V_t, V_a, R_t, R_a

# Compute the slope of the Geiger plateau
slope, V_t, V_a, R_t, R_a = compute_geiger_plateau_slope(v, rate)

# Plotting the data
plt.figure(figsize=(12, 8))

# Linear Interpolation
plt.subplot(2, 2, 1)
plt.plot(v_smooth, rate_smooth_linear, color='b', label='Linear Interpolation')
plt.errorbar(v, rate, xerr=np.full_like(v, 5), yerr=np.full_like(rate, 2), fmt='r.', label='Data Points with Error')
plt.axvline(V_t, color='g', linestyle='--', label=f'Vt = {V_t} V')
plt.axvline(V_a, color='m', linestyle='--', label=f'Va = {V_a} V')
plt.title('Linear Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# B-Spline Interpolation
plt.subplot(2, 2, 2)
plt.plot(v_smooth, rate_smooth_bspline, color='b', label='B-Spline Smoothed Curve')
plt.errorbar(v, rate, xerr=np.full_like(v, 5), yerr=np.full_like(rate, 2), fmt='r.', label='Data Points with Error')
plt.axvline(V_t, color='g', linestyle='--', label=f'Vt = {V_t} V')
plt.axvline(V_a, color='m', linestyle='--', label=f'Va = {V_a} V')
plt.title('B-Spline Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# Akima Interpolation
plt.subplot(2, 2, 3)
plt.plot(v_smooth, rate_smooth_akima, color='b', label='Akima Interpolation')
plt.errorbar(v, rate, xerr=np.full_like(v, 5), yerr=np.full_like(rate, 2), fmt='r.', label='Data Points with Error')
plt.axvline(V_t, color='g', linestyle='--', label=f'Vt = {V_t} V')
plt.axvline(V_a, color='m', linestyle='--', label=f'Va = {V_a} V')
plt.title('Akima Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# PCHIP Interpolation
plt.subplot(2, 2, 4)
plt.plot(v_smooth, rate_smooth_pchip, color='b', label='PCHIP Interpolation')
plt.errorbar(v, rate, xerr=np.full_like(v, 5), yerr=np.full_like(rate, 2), fmt='r.', label='Data Points with Error')
plt.axvline(V_t, color='g', linestyle='--', label=f'Vt = {V_t} V')
plt.axvline(V_a, color='m', linestyle='--', label=f'Va = {V_a} V')
plt.title('PCHIP Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

print(f"Slope of the Geiger plateau: {slope:.2f}%")
print(f"Threshold Voltage (V_t): {V_t} V, Count Rate (R_t): {R_t}")
print(f"Breakdown Voltage (V_a): {V_a} V, Count Rate (R_a): {R_a}")
# Out:
# Slope of the Geiger plateau: 0.11%
# Threshold Voltage (V_t): 820 V, Count Rate (R_t): 29.2111111
# Breakdown Voltage (V_a): 1200 V, Count Rate (R_a): 44.4777778

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d, splrep, splev, Akima1DInterpolator, PchipInterpolator

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 6.61111111, 29.2111111, 32.6333333, 33.5111111, 34.4777778, 34.7777778, 35.5666667, 36.0222222, 35.7888889, 36.4888889, 36.9111111, 
                 37.3555556, 37.0777778, 38.8555556, 38.0888889, 39.9, 40.2777778, 41.4111111, 41.1, 41.8666667, 44.4777778, 67.7444444])

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)

# Linear Interpolation
linear_interp = interp1d(v, rate)
rate_smooth_linear = linear_interp(v_smooth)

# B-Spline Interpolation
spl = splrep(v, rate)
rate_smooth_bspline = splev(v_smooth, spl)

# Akima Interpolation
akima_interp = Akima1DInterpolator(v, rate)
rate_smooth_akima = akima_interp(v_smooth)

# PCHIP Interpolation
pchip_interp = PchipInterpolator(v, rate)
rate_smooth_pchip = pchip_interp(v_smooth)

def compute_geiger_plateau_slope(v, rate):
    # Calculate gradient
    gradients = np.gradient(rate, v)
    
    # Calculate the second derivative (change in gradients)
    second_gradients = np.gradient(gradients, v)
    
    # Identify the threshold voltage (V_t) where the gradient suddenly decreases to a small value
    V_t_index = np.argmin(second_gradients)
    
    # Identify the breakdown voltage (V_a) where the gradient suddenly increases to a large value
    V_a_index = np.argmax(second_gradients)
    
    V_t = v[V_t_index]
    V_a = v[V_a_index]
    R_t = rate[V_t_index]
    R_a = rate[V_a_index]
    
    # Compute the slope using the given formula
    slope = ((R_a - R_t) / (0.5 * (R_a + R_t) * (V_a - V_t))) * 100
    
    return slope, V_t, V_a, R_t, R_a

# Compute the slope of the Geiger plateau
slope, V_t, V_a, R_t, R_a = compute_geiger_plateau_slope(v, rate)

# Plotting the data
plt.figure(figsize=(12, 8))

# Linear Interpolation
plt.subplot(2, 2, 1)
plt.plot(v_smooth, rate_smooth_linear, color='b', label='Linear Interpolation')
plt.errorbar(v, rate, xerr=np.full_like(v, 5), yerr=np.full_like(rate, 2), fmt='r.', label='Data Points with Error')
plt.axvline(V_t, color='g', linestyle='--', label=f'Vt = {V_t} V')
plt.axvline(V_a, color='m', linestyle='--', label=f'Va = {V_a} V')
plt.title('Linear Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# B-Spline Interpolation
plt.subplot(2, 2, 2)
plt.plot(v_smooth, rate_smooth_bspline, color='b', label='B-Spline Smoothed Curve')
plt.errorbar(v, rate, xerr=np.full_like(v, 5), yerr=np.full_like(rate, 2), fmt='r.', label='Data Points with Error')
plt.axvline(V_t, color='g', linestyle='--', label=f'Vt = {V_t} V')
plt.axvline(V_a, color='m', linestyle='--', label=f'Va = {V_a} V')
plt.title('B-Spline Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# Akima Interpolation
plt.subplot(2, 2, 3)
plt.plot(v_smooth, rate_smooth_akima, color='b', label='Akima Interpolation')
plt.errorbar(v, rate, xerr=np.full_like(v, 5), yerr=np.full_like(rate, 2), fmt='r.', label='Data Points with Error')
plt.axvline(V_t, color='g', linestyle='--', label=f'Vt = {V_t} V')
plt.axvline(V_a, color='m', linestyle='--', label=f'Va = {V_a} V')
plt.title('Akima Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# PCHIP Interpolation
plt.subplot(2, 2, 4)
plt.plot(v_smooth, rate_smooth_pchip, color='b', label='PCHIP Interpolation')
plt.errorbar(v, rate, xerr=np.full_like(v, 5), yerr=np.full_like(rate, 2), fmt='r.', label='Data Points with Error')
plt.axvline(V_t, color='g', linestyle='--', label=f'Vt = {V_t} V')
plt.axvline(V_a, color='m', linestyle='--', label=f'Va = {V_a} V')
plt.title('PCHIP Interpolation')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

print(f"Slope of the Geiger plateau: {slope:.2f}%")
print(f"Threshold Voltage (V_t): {V_t} V, Count Rate (R_t): {R_t}")
print(f"Breakdown Voltage (V_a): {V_a} V, Count Rate (R_a): {R_a}")
# Out:
# Slope of the Geiger plateau: 0.11%
# Threshold Voltage (V_t): 820 V, Count Rate (R_t): 29.2111111
# Breakdown Voltage (V_a): 1200 V, Count Rate (R_a): 44.4777778

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d, splrep, splev, Akima1DInterpolator, PchipInterpolator

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 66.44444444, 89.8, 96.5, 99.86666667, 101.9777778, 103.6888889, 105.1444444, 107.5, 108.4333333, 109.7888889, 113.0777778, 
                          111.2444444, 114.8888889, 115.8333333, 117.3, 118.5111111, 123.9444444, 120, 124.5, 125.1444444, 130.2888889, 224.2111111])

# Create a range of values for a smooth curve
v_smooth = np.linspace(v.min(), v.max(), 500)

# Linear Interpolation
linear_interp = interp1d(v, rate)
rate_smooth_linear = linear_interp(v_smooth)

# B-Spline Interpolation
spl = splrep(v, rate)
rate_smooth_bspline = splev(v_smooth, spl)

# Akima Interpolation
akima_interp = Akima1DInterpolator(v, rate)
rate_smooth_akima = akima_interp(v_smooth)

# PCHIP Interpolation
pchip_interp = PchipInterpolator(v, rate)
rate_smooth_pchip = pchip_interp(v_smooth)

def compute_geiger_plateau_slope(v, rate):
    # Calculate gradient
    gradients = np.gradient(rate, v)
    
    # Calculate the second gradient (change of gradients)
    second_gradients = np.gradient(gradients, v)

    # Identify threshold voltage (V_t) where gradient suddenly decreases significantly
    V_t_index = np.argmin(second_gradients)
    # Identify breakdown voltage (V_a) where gradient suddenly increases significantly
    V_a_index = np.argmax(second_gradients)

    V_t = v[V_t_index]
    V_a = v[V_a_index]
    R_t = rate[V_t_index]
    R_a = rate[V_a_index]

    # Compute the slope using the given formula
    slope = ((R_a - R_t) / (0.5 * (R_a + R_t) * (V_a - V_t))) * 100

    return slope, V_t, V_a, R_t, R_a

# Compute the slope of the Geiger plateau
slope, V_t, V_a, R_t, R_a = compute_geiger_plateau_slope(v, rate)

# Assuming arbitrary errors for demonstration
v_error = np.full_like(v, 5)  # Error in voltage
rate_error = np.full_like(rate, 2)  # Error in count rate

# Fit straight lines to the specified segments
fit_1_2 = np.polyfit(v[:2], rate[:2], 1)
fit_3_22 = np.polyfit(v[2:22], rate[2:22], 1)
fit_22_23 = np.polyfit(v[22:], rate[22:], 1)

# Generate the linear fits for plotting
v_fit_1_2 = np.linspace(v[0], v[1], 100)
rate_fit_1_2 = np.polyval(fit_1_2, v_fit_1_2)

v_fit_3_22 = np.linspace(v[2], v[21], 100)
rate_fit_3_22 = np.polyval(fit_3_22, v_fit_3_22)

v_fit_22_23 = np.linspace(v[22], v[22], 100)
rate_fit_22_23 = np.polyval(fit_22_23, v_fit_22_23)

# Plotting the data and the linear fits
plt.figure(figsize=(12, 8))

# Linear Interpolation
plt.subplot(2, 2, 1)
plt.plot(v_smooth, rate_smooth_linear, color='b', label='Linear Interpolation')
plt.errorbar(v, rate, xerr=v_error, yerr=rate_error, fmt='r.', label='Data Points with Error', elinewidth=2, capsize=4)
plt.plot(v_fit_1_2, rate_fit_1_2, 'g--', label='Fit 1-2')
plt.plot(v_fit_3_22, rate_fit_3_22, 'm--', label='Fit 3-22')
plt.plot(v_fit_22_23, rate_fit_22_23, 'c--', label='Fit 22-23')
plt.title('Linear Interpolation with Linear Fits')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# B-Spline Interpolation
plt.subplot(2, 2, 2)
plt.plot(v_smooth, rate_smooth_bspline, color='b', label='B-Spline Smoothed Curve')
plt.errorbar(v, rate, xerr=v_error, yerr=rate_error, fmt='r.', label='Data Points with Error', elinewidth=2, capsize=4)
plt.plot(v_fit_1_2, rate_fit_1_2, 'g--', label='Fit 1-2')
plt.plot(v_fit_3_22, rate_fit_3_22, 'm--', label='Fit 3-22')
plt.plot(v_fit_22_23, rate_fit_22_23, 'c--', label='Fit 22-23')
plt.title('B-Spline Interpolation with Linear Fits')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# Akima Interpolation
plt.subplot(2, 2, 3)
plt.plot(v_smooth, rate_smooth_akima, color='b', label='Akima Interpolation')
plt.errorbar(v, rate, xerr=v_error, yerr=rate_error, fmt='r.', label='Data Points with Error', elinewidth=2, capsize=4)
plt.plot(v_fit_1_2, rate_fit_1_2, 'g--', label='Fit 1-2')
plt.plot(v_fit_3_22, rate_fit_3_22, 'm--', label='Fit 3-22')
plt.plot(v_fit_22_23, rate_fit_22_23, 'c--', label='Fit 22-23')
plt.title('Akima Interpolation with Linear Fits')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# PCHIP Interpolation
plt.subplot(2, 2, 4)
plt.plot(v_smooth, rate_smooth_pchip, color='b', label='PCHIP Interpolation')
plt.errorbar(v, rate, xerr=v_error, yerr=rate_error, fmt='r.', label='Data Points with Error', elinewidth=2, capsize=4)
plt.plot(v_fit_1_2, rate_fit_1_2, 'g--', label='Fit 1-2')
plt.plot(v_fit_3_22, rate_fit_3_22, 'm--', label='Fit 3-22')
plt.plot(v_fit_22_23, rate_fit_22_23, 'c--', label='Fit 22-23')
plt.title('PCHIP Interpolation with Linear Fits')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_25088\2783489839.py:61: RankWarning: Polyfit may be poorly conditioned
#   fit_22_23 = np.polyfit(v[22:], rate[22:], 1)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d, splrep, splev, Akima1DInterpolator, PchipInterpolator

# Data from the image
v = np.array([780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220])
rate = np.array([0, 66.44444444, 89.8, 96.5, 99.86666667, 101.9777778, 103.6888889, 105.1444444, 107.5, 108.4333333, 109.7888889, 113.0777778, 
                          111.2444444, 114.8888889, 115.8333333, 117.3, 118.5111111, 123.9444444, 120, 124.5, 125.1444444, 130.2888889, 224.2111111])

# Assuming arbitrary errors for demonstration
v_error = np.full_like(v, 5)  # Error in voltage
rate_error = np.full_like(rate, 2)  # Error in count rate

# Fit straight lines to the specified segments
fit_1_2 = np.polyfit(v[:2], rate[:2], 1)
fit_3_22 = np.polyfit(v[2:22], rate[2:22], 1)
fit_22_23 = np.polyfit(v[21:], rate[21:], 1)

# Generate the linear fits for plotting, extended range
v_fit_1_2 = np.linspace(v[0], v[2], 100)
rate_fit_1_2 = np.polyval(fit_1_2, v_fit_1_2)

v_fit_3_22 = np.linspace(v[0], v[-1], 100)
rate_fit_3_22 = np.polyval(fit_3_22, v_fit_3_22)

v_fit_22_23 = np.linspace(v[20], v[-1], 100)
rate_fit_22_23 = np.polyval(fit_22_23, v_fit_22_23)

# Plotting the data and the linear fits
plt.figure(figsize=(12, 8))

# Linear Interpolation
plt.subplot(2, 2, 1)
plt.plot(v_smooth, rate_smooth_linear, color='b', label='Linear Interpolation')
plt.errorbar(v, rate, xerr=v_error, yerr=rate_error, fmt='r.', label='Data Points with Error', elinewidth=2, capsize=4)
plt.plot(v_fit_1_2, rate_fit_1_2, 'g--', label='Fit 1-2')
plt.plot(v_fit_3_22, rate_fit_3_22, 'm--', label='Fit 3-22')
plt.plot(v_fit_22_23, rate_fit_22_23, 'c--', label='Fit 22-23')
plt.title('Linear Interpolation with Extended Linear Fits')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# B-Spline Interpolation
plt.subplot(2, 2, 2)
plt.plot(v_smooth, rate_smooth_bspline, color='b', label='B-Spline Smoothed Curve')
plt.errorbar(v, rate, xerr=v_error, yerr=rate_error, fmt='r.', label='Data Points with Error', elinewidth=2, capsize=4)
plt.plot(v_fit_1_2, rate_fit_1_2, 'g--', label='Fit 1-2')
plt.plot(v_fit_3_22, rate_fit_3_22, 'm--', label='Fit 3-22')
plt.plot(v_fit_22_23, rate_fit_22_23, 'c--', label='Fit 22-23')
plt.title('B-Spline Interpolation with Extended Linear Fits')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# Akima Interpolation
plt.subplot(2, 2, 3)
plt.plot(v_smooth, rate_smooth_akima, color='b', label='Akima Interpolation')
plt.errorbar(v, rate, xerr=v_error, yerr=rate_error, fmt='r.', label='Data Points with Error', elinewidth=2, capsize=4)
plt.plot(v_fit_1_2, rate_fit_1_2, 'g--', label='Fit 1-2')
plt.plot(v_fit_3_22, rate_fit_3_22, 'm--', label='Fit 3-22')
plt.plot(v_fit_22_23, rate_fit_22_23, 'c--', label='Fit 22-23')
plt.title('Akima Interpolation with Extended Linear Fits')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

# PCHIP Interpolation
plt.subplot(2, 2, 4)
plt.plot(v_smooth, rate_smooth_pchip, color='b', label='PCHIP Interpolation')
plt.errorbar(v, rate, xerr=v_error, yerr=rate_error, fmt='r.', label='Data Points with Error', elinewidth=2, capsize=4)
plt.plot(v_fit_1_2, rate_fit_1_2, 'g--', label='Fit 1-2')
plt.plot(v_fit_3_22, rate_fit_3_22, 'm--', label='Fit 3-22')
plt.plot(v_fit_22_23, rate_fit_22_23, 'c--', label='Fit 22-23')
plt.title('PCHIP Interpolation with Extended Linear Fits')
plt.xlabel('Applied Voltage (V)')
plt.ylabel('Count Rate')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
